# %% [markdown]
# ![car](car.jpg)
#
# Insurance companies invest a lot of [time and money](https://www.accenture.com/_acnmedia/pdf-84/accenture-machine-leaning-insurance.pdf) into optimizing their pricing and accurately estimating the likelihood that customers will make a claim. In many countries insurance it is a legal requirement to have car insurance in order to drive a vehicle on public roads, so the market is very large!
#
# Knowing all of this, On the Road car insurance have requested your services in building a model to predict whether a customer will make a claim on their insurance during the policy period. As they have very little expertise and infrastructure for deploying and monitoring machine learning models, they've asked you to identify the single feature that results in the best performing model, as measured by accuracy, so they can start with a simple model in production.
#
# They have supplied you with their customer data as a csv file called `car_insurance.csv`, along with a table detailing the column names and descriptions below.

# %% [markdown]
# ## The dataset
#
# | Column | Description |
# |--------|-------------|
# | `id` | Unique client identifier |
# | `age` | Client's age: <br> <ul><li>`0`: 16-15</li><li>`1`: 26-39</li><li>`2`: 40-64</li><li>`3`: 65+</li></ul> |
# | `gender` | Client's gender: <br> <ul><li>`0`: Female</li><li>`1`: Male</li></ul> |
# | `driving_experience` | Years the client has been driving: <br> <ul><li>`0`: 0-9</li><li>`1`: 10-19</li><li>`2`: 20-29</li><li>`3`: 30+</li></ul> |
# | `education` | Client's level of education: <br> <ul><li>`0`: No education</li><li>`1`: High school</li><li>`2`: University</li></ul> |
# | `income` | Client's income level: <br> <ul><li>`0`: Poverty</li><li>`1`: Working class</li><li>`2`: Middle class</li><li>`3`: Upper class</li></ul> |
# | `credit_score` | Client's credit score (between zero and one) |
# | `vehicle_ownership` | Client's vehicle ownership status: <br><ul><li>`0`: Does not own their vehilce (paying off finance)</li><li>`1`: Owns their vehicle</li></ul> |
# | `vehcile_year` | Year of vehicle registration: <br><ul><li>`0`: Before 2015</li><li>`1`: 2015 or later</li></ul> |
# | `married` | Client's marital status: <br><ul><li>`0`: Not married</li><li>`1`: Married</li></ul> |
# | `children` | Client's number of children |
# | `postal_code` | Client's postal code |
# | `annual_mileage` | Number of miles driven by the client each year |
# | `vehicle_type` | Type of car: <br> <ul><li>`0`: Sedan</li><li>`1`: Sports car</li></ul> |
# | `speeding_violations` | Total number of speeding violations received by the client |
# | `duis` | Number of times the client has been caught driving under the influence of alcohol |
# | `past_accidents` | Total number of previous accidents the client has been involved in |
# | `outcome` | Whether the client made a claim on their car insurance (response variable): <br><ul><li>`0`: No claim</li><li>`1`: Made a claim</li></ul> |

# %%
# Import required modules
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import accuracy_score

# Create DataFrame from .csv, Fill NaN values with the mean of each column where applicable
df = pd.read_csv('car_insurance.csv').fillna(df.mean(numeric_only=True))

# We are interested in the correlation of all columns with 'outcome'
correlation_matrix = df.corr()

# Display the correlation with 'outcome'
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ed235_row0_col0, #T_ed235_row1_col1, #T_ed235_row2_col2, #T_ed235_row3_col3, #T_ed235_row4_col4, #T_ed235_row5_col5, #T_ed235_row6_col6, #T_ed235_row7_col7, #T_ed235_row8_col8, #T_ed235_row9_col9, #T_ed235_row10_col10, #T_ed235_row11_col11, #T_ed235_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ed235_row0_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ed235_row0_col2, #T_ed235_row8_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ed235_row0_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ed235_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_ed235_row0_col5, #T_ed235_row2_col1, #T_ed235_row7_col1, #T_ed235_row7_col5, #T_ed235_row7_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ed235_row0_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ed235_row0_col7, #T_ed235_row1_col7, #T_ed235_row3_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ed235_row0_col8, #T_ed235_row0_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ed235_row0_col9, #T_ed235_row0_col11, #T_ed235_row2_col10, #T_ed235_row4_col8 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_ed235_row0_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ed235_row1_col0, #T_ed235_row5_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ed235_row1_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ed235_row1_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_ed235_row1_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_ed235_row1_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_ed235_row1_col6 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_ed235_row1_col8, #T_ed235_row5_col7, #T_ed235_row12_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ed235_row1_col9 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_ed235_row1_col10, #T_ed235_row6_col3, #T_ed235_row6_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_ed235_row1_col11 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ed235_row1_col12, #T_ed235_row2_col0, #T_ed235_row3_col2, #T_ed235_row5_col8, #T_ed235_row8_col5, #T_ed235_row8_col6, #T_ed235_row8_col7, #T_ed235_row8_col9, #T_ed235_row12_col0, #T_ed235_row12_col1, #T_ed235_row12_col3, #T_ed235_row12_col4, #T_ed235_row12_col10, #T_ed235_row12_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ed235_row2_col3, #T_ed235_row10_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ed235_row2_col4, #T_ed235_row11_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ed235_row2_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ed235_row2_col6, #T_ed235_row2_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ed235_row2_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_ed235_row2_col9, #T_ed235_row4_col6, #T_ed235_row10_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_ed235_row2_col11 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_ed235_row2_col12, #T_ed235_row3_col9, #T_ed235_row9_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ed235_row3_col0, #T_ed235_row11_col0, #T_ed235_row12_col9 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ed235_row3_col1 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ed235_row3_col4, #T_ed235_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ed235_row3_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ed235_row3_col8, #T_ed235_row12_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_ed235_row3_col10, #T_ed235_row5_col10, #T_ed235_row9_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_ed235_row3_col11, #T_ed235_row11_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ed235_row3_col12, #T_ed235_row8_col11, #T_ed235_row11_col12 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ed235_row4_col0, #T_ed235_row7_col0, #T_ed235_row9_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ed235_row4_col1, #T_ed235_row5_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ed235_row4_col2, #T_ed235_row5_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ed235_row4_col3, #T_ed235_row9_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_ed235_row4_col5, #T_ed235_row12_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ed235_row4_col7, #T_ed235_row9_col12 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ed235_row4_col9, #T_ed235_row10_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ed235_row4_col10 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ed235_row4_col11, #T_ed235_row10_col3 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_ed235_row4_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ed235_row5_col1, #T_ed235_row6_col1, #T_ed235_row9_col11, #T_ed235_row11_col9 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_ed235_row5_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_ed235_row5_col4, #T_ed235_row5_col11 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_ed235_row5_col9, #T_ed235_row6_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ed235_row5_col12, #T_ed235_row8_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ed235_row6_col0, #T_ed235_row6_col8, #T_ed235_row8_col0, #T_ed235_row11_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ed235_row6_col2, #T_ed235_row7_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ed235_row6_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ed235_row6_col5, #T_ed235_row10_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_ed235_row6_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ed235_row6_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ed235_row6_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ed235_row7_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ed235_row7_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ed235_row7_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ed235_row7_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ed235_row7_col10 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ed235_row7_col11, #T_ed235_row10_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ed235_row7_col12, #T_ed235_row11_col10 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ed235_row8_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ed235_row8_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ed235_row8_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ed235_row8_col12 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_ed235_row9_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_ed235_row9_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ed235_row9_col5 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_ed235_row9_col6, #T_ed235_row11_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ed235_row9_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ed235_row9_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ed235_row10_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ed235_row10_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ed235_row10_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ed235_row10_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ed235_row10_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_ed235_row10_col11 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_ed235_row11_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_ed235_row11_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_ed235_row11_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_ed235_row11_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ed235_row12_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_ed235_row12_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ed235">
#   <thead>
#     <tr>
#       <th class="bl

# %%
features = df.drop(columns=["id", "outcome"]).columns

# Dictionary to store performance metrics
model_list = []

# Loop through features
for col in features:
    # Create a model
    model = logit(f"outcome ~ {col}", data=df).fit()
    # Add each model to the models list
    model_list.append(model)

# Empty list to store accuracies
accuracies = []

# Loop through models
for feature in range(0, len(model_list)):
    # Compute the confusion matrix
    conf_matrix = model_list[feature].pred_table()
    # True negatives
    tn = conf_matrix[0,0]
    # True positives
    tp = conf_matrix[1,1]
    # False negatives
    fn = conf_matrix[1,0]
    # False positives
    fp = conf_matrix[0,1]
    # Compute accuracy
    acc = (tn + tp) / (tn + fn + fp + tp)
    accuracies.append(acc)
    
# Find the feature with the largest accuracy
best_feature = features[accuracies.index(max(accuracies))]

# Create best_feature_df
best_feature_df = pd.DataFrame({"best_feature": best_feature,
                                "best_accuracy": max(accuracies)},
                                index=[0])
print(best_feature_df)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.511794
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.615951
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.467092
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.603742
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.531499
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572557
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.552412
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.572668
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.586659
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595431
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.617345
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605716
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.621700
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.558922
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.598699
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.549220
#          Iterations 7
#          best_feature  best_accuracy
# 0  driving_experience         0.7771
